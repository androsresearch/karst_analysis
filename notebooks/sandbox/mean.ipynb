# %%
import sys
import os

root = os.path.abspath('../..')  
sys.path.append(root)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import modules.statistics_fwl_estimation as st_fwl

# from modules import processing, load, plots, analysis

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 25)

# %%
df = pd.read_csv(f'{root}/notebooks/sandbox/p7a_oct_2017.csv')

df
# Out:
#      Unnamed: 0       DateTime   Temp  SpCond PressureA   Depth    Cond  \
# 0           NaN          M/D/Y      C   mS/cm      psia       m   mS/cm
# 1           1.0  5/10/17 16:51  28.09   4.013     15.02   0.053    4.25
# 2           2.0  5/10/17 16:51  28.08   4.007     15.43   0.343   4.243
# 3           3.0  5/10/17 16:51  28.06   3.997     15.54   0.416   4.231
# 4           4.0  5/10/17 16:51  27.99   3.991     15.68   0.514   4.219
# ..          ...            ...    ...     ...       ...     ...     ...
# 149       149.0  5/10/17 16:58   26.4  53.515     38.39  16.119  54.946
# 150       150.0  5/10/17 16:59   26.4  53.518     38.45   16.16  54.949
# 151       151.0  5/10/17 16:59   26.4   53.52     38.55  16.227  54.952
# 152       152.0  5/10/17 16:59   26.4  53.525     38.67  16.312  54.958
# 153       153.0  5/10/17 16:59   26.4   53.52     38.72  16.346  54.955
#
#     Salinity     TDS
# 0        ppt     g/L
# 1       2.11   2.609
# 2       2.11   2.605
# 3        2.1   2.598
# 4        2.1   2.594
# ..       ...     ...
# 149     35.3  34.785
# 150     35.3  34.786
# 151     35.3  34.788
# 152    35.31  34.791
# 153     35.3  34.788
#
# [154 rows x 9 columns]

# %%
df = df.drop(0)
df = df.reset_index(drop=True)

df
# Out:
#      Unnamed: 0       DateTime   Temp  SpCond PressureA   Depth    Cond  \
# 0           1.0  5/10/17 16:51  28.09   4.013     15.02   0.053    4.25
# 1           2.0  5/10/17 16:51  28.08   4.007     15.43   0.343   4.243
# 2           3.0  5/10/17 16:51  28.06   3.997     15.54   0.416   4.231
# 3           4.0  5/10/17 16:51  27.99   3.991     15.68   0.514   4.219
# 4           5.0  5/10/17 16:51  27.89   3.989     16.09   0.804   4.209
# ..          ...            ...    ...     ...       ...     ...     ...
# 148       149.0  5/10/17 16:58   26.4  53.515     38.39  16.119  54.946
# 149       150.0  5/10/17 16:59   26.4  53.518     38.45   16.16  54.949
# 150       151.0  5/10/17 16:59   26.4   53.52     38.55  16.227  54.952
# 151       152.0  5/10/17 16:59   26.4  53.525     38.67  16.312  54.958
# 152       153.0  5/10/17 16:59   26.4   53.52     38.72  16.346  54.955
#
#     Salinity     TDS
# 0       2.11   2.609
# 1       2.11   2.605
# 2        2.1   2.598
# 3        2.1   2.594
# 4        2.1   2.593
# ..       ...     ...
# 148     35.3  34.785
# 149     35.3  34.786
# 150     35.3  34.788
# 151    35.31  34.791
# 152     35.3  34.788
#
# [153 rows x 9 columns]

# %%
df[['Depth', 'SpCond']] = df[['Depth', 'SpCond']].astype(float)

fig = px.scatter(df, x='Depth', y='SpCond', title='Profundidad vs Conductividad Específica')
fig.update_layout(
    xaxis_title='Profundidad (m)',
    yaxis_title='Conductividad Específica (mS/cm)'
)
fig.show()

# %%
df = df[(df['Depth'].astype(float) >= 10.33) & (df['Depth'].astype(float) <= 11.58)]

media_spcond = df['SpCond'].astype(float).mean()
print(f"La conductividad específica media es: {media_spcond:.3f} mS/cm")
# Out:
# La conductividad específica media es: 25.869 mS/cm

# %%
df = df[df['Depth'].astype(float) > 11.58]

df_spcond = df['SpCond'].astype(float)
media_spcond = df_spcond.mean()
print(f"La conductividad específica media es: {media_spcond:.3f} mS/cm")
# Out:
# La conductividad específica media es: 50.243 mS/cm

# %%
df = df[df['Depth'].astype(float) < 10]

df_spcond = df['SpCond']
df_spcond = df_spcond.astype(float)
media_spcond = df_spcond.mean()
print(f"La conductividad específica media es: {media_spcond:.3f} mS/cm")
# Out:
# La conductividad específica media es: 3.835 mS/cm

# %%
df_spcond = df[['SpCond' < ]]

df_spcond = df_spcond.astype(float)
media_spcond = df_spcond.mean()
print(f"La conductividad específica media es: {media_spcond:.3f} mS/cm")
# Out:
# La conductividad específica media es: 20.261 mS/cm

# %%
df_depth = df['Depth']

df_depth = df_depth.astype(float)

df_depth.mean()
# Out:
# np.float64(8.96924183006536)

# %%
df[['Depth', 'SpCond']].astype(float).plot(x='Depth', y='SpCond')
# Out:
# <Axes: xlabel='Depth'>
